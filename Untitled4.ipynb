# %%
import torch
from diffusers import CogVideoXImageToVideoPipeline
from diffusers.utils import export_to_video, load_image

prompt = "A vast, shimmering ocean flows gracefully under a twilight sky, its waves undulating in a mesmerizing dance of blues and greens. The surface glints with the last rays of the setting sun, casting golden highlights that ripple across the water. Seagulls soar above, their cries blending with the gentle roar of the waves. The horizon stretches infinitely, where the ocean meets the sky in a seamless blend of hues. Close-ups reveal the intricate patterns of the waves, capturing the fluidity and dynamic beauty of the sea in motion."
image = load_image(image="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRuHfegiTYCw9i8t6OPsSNevSo2FTuXC7NucQ&s")
pipe = CogVideoXImageToVideoPipeline.from_pretrained(
    "THUDM/CogVideoX-5b-I2V",
    torch_dtype=torch.bfloat16
)
# Out:
# model_index.json:   0%|          | 0.00/423 [00:00<?, ?B/s]
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer/added_tokens.json:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# (…)ext_encoder/model.safetensors.index.json:   0%|          | 0.00/19.9k [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/782 [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.53G [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# (…)pytorch_model-00002-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# (…)pytorch_model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# (…)pytorch_model-00003-of-00003.safetensors:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/20.6k [00:00<?, ?B/s]
# (…)ion_pytorch_model.safetensors.index.json:   0%|          | 0.00/103k [00:00<?, ?B/s]
# transformer/config.json:   0%|          | 0.00/802 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/431M [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/839 [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from IPython.display import display, HTML

display(prompt)
display(image)
# Out:
# 'A vast, shimmering ocean flows gracefully under a twilight sky, its waves undulating in a mesmerizing dance of blues and greens. The surface glints with the last rays of the setting sun, casting golden highlights that ripple across the water. Seagulls soar above, their cries blending with the gentle roar of the waves. The horizon stretches infinitely, where the ocean meets the sky in a seamless blend of hues. Close-ups reveal the intricate patterns of the waves, capturing the fluidity and dynamic beauty of the sea in motion.'
# <PIL.Image.Image image mode=RGB size=183x276>

# %%
pipe.vae.enable_tiling()
pipe.vae.enable_slicing()

video = pipe(
    prompt=prompt,
    image=image,
    num_videos_per_prompt=1,
    num_inference_steps=50,
    num_frames=49,
    guidance_scale=6,
    generator=torch.Generator(device="cuda").manual_seed(42),
).frames[0]

export_to_video(video, "output.mp4", fps=8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_517575/2082238284.py in <cell line: 4>()
#       2 pipe.vae.enable_slicing()
#       3
# ----> 4 video = pipe(
#       5     prompt=prompt,
#       6     image=image,
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/pipelines/cogvideo/pipeline_cogvideox_image2video.py in __call__(self, image, prompt, negative_prompt, height, width, num_frames, num_inference_steps, timesteps, guidance_scale, use_dynamic_cfg, num_videos_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, output_type, return_dict, attention_kwargs, callback_on_step_end, callback_on_step_end_tensor_inputs, max_sequence_length)
#     732
#     733         latent_channels = self.transformer.config.in_channels // 2
# --> 734         latents, image_latents = self.prepare_latents(
#     735             image,
#     736             batch_size * num_videos_per_prompt,
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/pipelines/cogvideo/pipeline_cogvideox_image2video.py in prepare_latents(self, image, batch_size, num_channels_latents, num_frames, height, width, dtype, device, generator, latents)
#     375             ]
#     376         else:
# --> 377             image_latents = [retrieve_latents(self.vae.encode(img.unsqueeze(0)), generator) for img in image]
#     378
#     379         image_latents = torch.cat(image_latents, dim=0).to(dtype).permute(0, 2, 1, 3, 4)  # [B, F, C, H, W]
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/pipelines/cogvideo/pipeline_cogvideox_image2video.py in <listcomp>(.0)
#     375             ]
#     376         else:
# --> 377             image_latents = [retrieve_latents(self.vae.encode(img.unsqueeze(0)), generator) for img in image]
#     378
#     379         image_latents = torch.cat(image_latents, dim=0).to(dtype).permute(0, 2, 1, 3, 4)  # [B, F, C, H, W]
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/pipelines/cogvideo/pipeline_cogvideox_image2video.py in retrieve_latents(encoder_output, generator, sample_mode)
#     145 ):
#     146     if hasattr(encoder_output, "latent_dist") and sample_mode == "sample":
# --> 147         return encoder_output.latent_dist.sample(generator)
#     148     elif hasattr(encoder_output, "latent_dist") and sample_mode == "argmax":
#     149         return encoder_output.latent_dist.mode()
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/models/autoencoders/vae.py in sample(self, generator)
#     780     def sample(self, generator: Optional[torch.Generator] = None) -> torch.Tensor:
#     781         # make sure sample is on the same device as the parameters and has same dtype
# --> 782         sample = randn_tensor(
#     783             self.mean.shape,
#     784             generator=generator,
#
# ~/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/diffusers/utils/torch_utils.py in randn_tensor(shape, generator, device, dtype, layout)
#      65                 )
#      66         elif gen_device_type != device.type and gen_device_type == "cuda":
# ---> 67             raise ValueError(f"Cannot generate a {device} tensor from a generator of type {gen_device_type}.")
#      68
#      69     # make sure generator list of length 1 is treated like a non-list
#
# ValueError: Cannot generate a cpu tensor from a generator of type cuda.

# %%
import torch
from diffusers import StableVideoDiffusionPipeline
from diffusers.utils import load_image, export_to_video

pipeline = StableVideoDiffusionPipeline.from_pretrained(
    "stabilityai/stable-video-diffusion-img2vid-xt", torch_dtype=torch.float16, variant="fp16"
)
pipeline.enable_model_cpu_offload()
# Out:
# /home/coder/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/xformers/ops/fmha/flash.py:211: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_fwd")
# /home/coder/work/canva/tools/build/python/third_party/.venv/lib/python3.10/site-packages/xformers/ops/fmha/flash.py:344: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_bwd")
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
image = load_image("https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/svd/rocket.png")
image = image.resize((1024, 576))
image
# Out:
# <PIL.Image.Image image mode=RGB size=1024x576>

# %%
generator = torch.manual_seed(42)
frames = pipeline(image, decode_chunk_size=8, generator=generator).frames[0]
export_to_video(frames, "generated.mp4", fps=7)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# 'generated.mp4'

# %%
from IPython.display import Video

Video("generated.mp4")
# Out:
# <video src="generated.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
